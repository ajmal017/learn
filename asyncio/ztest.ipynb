# %%
import pickle
import pandas as pd
MARKET = 'SNP'

ROOT_PATH = r'C:/Users/User/Documents/Business/Projects/iboop/'
FSPATH = ROOT_PATH+r'data/'+MARKET.lower()+'/'

with open(FSPATH+'_dump.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
pd.read_pickle(FSPATH + '_df_unds.pkl')
